# %% [markdown]
# # 03 Build Models

# %% [markdown]
# ## Imports

# %% [markdown]
# * We want AUC ROC

# %%
import pandas as pd
import numpy as np
import pickle

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import confusion_matrix, roc_auc_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn import svm
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier





from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.utils import to_categorical
from keras.optimizers import Adam
from keras.layers import Dropout
from keras import regularizers



import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Functions

# %%
def get_metrics(y_true, y_predict, print_scores = True):
    matrix_def = [['tn','fp'], ['fn','tp']]
    matrix = confusion_matrix(y_true, y_predict)
    tn, fp, fn, tp = matrix.ravel()
    accuracy = (tp+tn)/(tn+fp+fn+tp)
    misclass = 1-accuracy
    sensitivity = tp/(tp+fn)
    specificity = tn/(tn+fp)
    precision = tp/(tp+fp)
    if print_scores:
        print('Matrix Definition')
        print(np.array(matrix_def))
        print('')
        print('Confusion Matrix')
        print(matrix)
        print('')
        print('METRICS')
        print('accuracy:', accuracy)
        print('misclass:', misclass)
        print('sensitivity:', sensitivity)
        print('specificity:', specificity)
    else:
        return accuracy, misclass, sensitivity, specificity, precision

# %% [markdown]
# ## Read in Train and Test Data

# %%
with open('../Cleansed_Data/X_train_ss.pkl','rb') as f:
    X_train_ss = pickle.load(f)
    
with open('../Cleansed_Data/X_test_ss.pkl','rb') as f:
    X_test_ss = pickle.load(f)
    
with open('../Cleansed_Data/y_train.pkl','rb') as f:
    y_train = pickle.load(f)
    
with open('../Cleansed_Data/y_test.pkl','rb') as f:
    y_test = pickle.load(f)

# %%
print([column for column in X.columns])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-acb9dbd21a3d> in <module>()
# ----> 1 print([column for column in X.columns])
#
# NameError: name 'X' is not defined

# %% [markdown]
# ## Try Simple Logistic Regression

# %%
lr = LogisticRegression()
lr.fit(X_train_ss, y_train)
lr.score(X_train_ss, y_train), lr.score(X_test_ss, y_test)

get_metrics(lr.predict(X_test_ss), y_test)
# Out:
# Matrix Definition
# [['tn' 'fp']
#  ['fn' 'tp']]
#
# Confusion Matrix
# [[1998  100]
#  [   7   14]]
#
# METRICS
# accuracy: 0.9495044832468146
# misclass: 0.05049551675318542
# sensitivity: 0.6666666666666666
# specificity: 0.9523355576739753

# %% [markdown]
# ## Try Neural Net

# %%
# Check number of inputs
print(X_train_ss.shape[1])
layer1 = X_train_ss.shape[1]
layer2 = 6
# Out:
# 167

# %%
model = Sequential()
model.add(Dense(layer1, activation='relu', input_dim=X_train_ss.shape[1])) #Makes this dynamic
model.add(Dropout(.4))
model.add(Dense(layer2, activation='relu')) #Makes this dynamic
model.add(Dense(1, activation='sigmoid'))

# %%
adam = Adam(lr=0.0001)
model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])  #mean_squared_error

# %%
history = model.fit(X_train_ss, y_train, validation_data=(X_test_ss, y_test), epochs=70, batch_size=32, verbose=0)

# %%
plt.plot(history.history['loss'], label= 'Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')

plt.legend()

# %%
plt.plot(history.history['acc'], label='Train Accuracy')
plt.plot(history.history['val_acc'], label='Test Accuracy')
plt.legend()

# %%
roc_auc_score(y_test, model.predict(X_test_ss))
# Out:
# 0.893748085925537

# %% [markdown]
# ------------
# -----------
#
# # Modeling:

# %% [markdown]
# #### Importing Data:

# %%
with open('../Cleansed_Data/X.pkl', 'rb') as f:
    X = pickle.load(f)
    
with open('../Cleansed_Data/y.pkl', 'rb') as f:
    y = pickle.load(f)

# %% [markdown]
# ## Preparing the Data with Train/Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=.30, 
                                                    stratify=y, 
                                                    random_state=42)

# %% [markdown]
# ## Scaling + Fitting:

# %%
ss = StandardScaler()

X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

# %% [markdown]
# ## Support Vector Machine:

# %%
clf = svm.SVC(gamma=0.25, 
              random_state=42)
cross_val_score(clf, X_train, y_train, scoring='roc_auc', cv=5).mean()
# Out:
# 0.613065547902153

# %%
svc = svm.SVC(
              kernel='linear',
              random_state=42)
cross_val_score(svc, X_train, y_train, scoring='roc_auc', cv=5).mean()
# Out:
# 0.8598011462842241

# %%
poly_svc = svm.SVC( 
              kernel='poly', 
              degree=1, 
              gamma=0.35, 
              random_state=42)
cross_val_score(poly_svc, X_train, y_train, scoring='roc_auc', cv=5).mean()
# Out:
# 0.8589523730442554

# %%
poly_svc = svm.SVC( 
              kernel='sigmoid', 
              random_state=42)
cross_val_score(poly_svc, X_train, y_train, scoring='roc_auc', cv=5).mean()
# Out:
# 0.644944552843399

# %% [markdown]
# ## Support Vector Machine w/ Principal Component Analysis
#
# ### Scaling and fitting the data using PCA:

# %%
pca = PCA()
ss = StandardScaler()
Xs = pca.fit_transform(X)

pca = PCA(n_components=2)
Xt = pca.fit_transform(Xs)

# %% [markdown]
# ### Sigmoid - Support Vector Machine w/ Principal Component Analysis

# %%
poly_svc = svm.SVC( 
              kernel='sigmoid', 
              random_state=42)

cross_val_score(poly_svc, Xt, y, scoring='roc_auc', cv=5).mean()
# Out:
# 0.5219595187102339

# %% [markdown]
# ### Sigmoid - Support Vector Machine w/ Principal Component Analysis

# %%
poly_svc = svm.SVC( 
              kernel='poly', 
              degree=1, 
              gamma=0.35, 
              random_state=42)
cross_val_score(poly_svc, Xt, y, scoring='accuracy', cv=5).mean()

# %% [markdown]
# --------

# %% [markdown]
# ## Random Forest

# %%
rf = RandomForestClassifier(n_estimators=100, max_depth=15, min_samples_leaf=3)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=15, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=3, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rf.score(X_train, y_train)
# Out:
# 0.9575185434929198

# %%
rf.score(X_test, y_test)
# Out:
# 0.9480928037750688

# %%
y_test.mean()
# Out:
# 0.05387337790011797

# %%
rf.predict(X_test).mean()
# Out:
# 0.01061738104600865

# %%
rf.predict_proba(X_test)
# Out:
# array([[1.        , 0.        ],
#        [0.98958087, 0.01041913],
#        [1.        , 0.        ],
#        ...,
#        [1.        , 0.        ],
#        [1.        , 0.        ],
#        [0.98045643, 0.01954357]])

# %%
roc_auc_score(y_test, rf.predict_proba(X_test)[:,1])
# Out:
# 0.8931579202844471

# %%
X_test.shape
# Out:
# (2543, 167)

# %% [markdown]
# ## Look at Feature Importances

# %%
feat_imp = pd.DataFrame(rf.feature_importances_, index=X.columns).sort_values(0, ascending=False)

# %%
feat_imp.head(20)
# Out:
#                                        0
# NumMosquitos                    0.299804
# Longitude                       0.180118
# Latitude                        0.168003
# Species_CULEX PIPIENS           0.020916
# Species_CULEX PIPIENS/RESTUANS  0.020322
# Species_CULEX RESTUANS          0.011955
# DewPointC_1_back                0.010203
# DewPointC_8_back                0.008725
# photoperiod_2_back              0.008484
# Month_08                        0.008148
# photoperiod_4_back              0.007938
# photoperiod_1_back              0.007876
# photoperiod                     0.007060
# photoperiod_7_back              0.006962
# TminC_2_back                    0.006779
# photoperiod_5_back              0.006240
# photoperiod_3_back              0.005462
# DewPointC                       0.005311
# DewPointC_2_back                0.004978
# photoperiod_10_back             0.004590

# %% [markdown]
# ## Import Kaggle Test Data

# %%
kaggle_X = pd.read_csv('../Cleansed_Data/test_final.csv')

# %%
X.columns
# Out:
# Index(['Latitude', 'Longitude', 'NumMosquitos', 'BR', 'HZ', 'RA', 'TSRA',
#        'VCTS', 'FU', 'TS',
#        ...
#        'Month_08', 'Month_09', 'Month_10', 'Species_CULEX ERRATICUS',
#        'Species_CULEX PIPIENS', 'Species_CULEX PIPIENS/RESTUANS',
#        'Species_CULEX RESTUANS', 'Species_CULEX SALINARIUS',
#        'Species_CULEX TARSALIS', 'Species_CULEX TERRITANS'],
#       dtype='object', length=167)

# %%
kaggle_X.NumMosquitos.value_counts()
# Out:
# -0.16018    116293
# Name: NumMosquitos, dtype: int64

# %%
kaggle_X.columns
# Out:
# Index(['Id', 'Latitude', 'Longitude', 'BR', 'HZ', 'RA', 'TSRA', 'VCTS', 'FU',
#        'TS',
#        ...
#        'Month_10', 'Species_CULEX ERRATICUS', 'Species_CULEX PIPIENS',
#        'Species_CULEX PIPIENS/RESTUANS', 'Species_CULEX RESTUANS',
#        'Species_CULEX SALINARIUS', 'Species_CULEX TARSALIS',
#        'Species_CULEX TERRITANS', 'Month_05', 'NumMosquitos'],
#       dtype='object', length=168)

# %%
kaggle_X = kaggle_X[X.columns]

# %%
preds = rf.predict_proba(kaggle_X)[:,1]

# %%
submission_df = pd.DataFrame(preds, index=kaggle_X.index, columns=['WnvPresent'])

# %%
submission_df.to_csv('../Cleansed_Data/rf_test.csv')

# %%
submission_df.WnvPresent.mean()
# Out:
# 0.04109916931264502

# %%
submission_df.describe()
# Out:
#           WnvPresent
# count  116293.000000
# mean        0.041099
# std         0.028155
# min         0.001273
# 25%         0.018860
# 50%         0.033414
# 75%         0.056272
# max         0.198809

# %%
indecies = submission_df[submission_df.WnvPresent > .1].index

# %%
locations_df = pd.read_csv("../west_nile/west_nile/input/test.csv")

# %%
spray_df = locations_df.loc[indecies, ['Latitude', 'Longitude', 'Date']]

# %%
spray_df.to_csv('../Cleansed_Data/predicted_spray.csv')

# %%
df = pd.read_csv('../west_nile/west_nile/input/train.csv')
mapdata = np.loadtxt("../west_nile/west_nile/input/mapdata_copyright_openstreetmap_contributors.txt")
traps = df[['Date', 'Trap','Longitude', 'Latitude', 'WnvPresent']]

aspect = mapdata.shape[0] * 1.0 / mapdata.shape[1]
lon_lat_box = (-88, -87.5, 41.6, 42.1)

plt.figure(figsize=(10,14))
plt.imshow(mapdata,
          cmap=plt.get_cmap('gray'),
          extent=lon_lat_box,
          aspect=aspect)

locations = traps[['Longitude', 'Latitude']].drop_duplicates().values
sprays = spray_df[['Longitude', 'Latitude']].drop_duplicates().values
plt.scatter(sprays[:,0], sprays[:,1], c='r', alpha=.5, s=200)
plt.scatter(locations[:,0], locations[:,1], marker='x')

# %%
# ada = AdaBoostClassifier()

# %%
# params = {}

# %%
# gs = GridSearchCV(ada, params)

# %%
# gs.fit(X_train, y_train)

# %%
# gs.score(X_train_tf, y_train)

# %%
# gs.score(X_test_tf, y_test)

# %%
with open('../Cleansed_Data/X.pkl', 'rb') as f:
    X = pickle.load(f)
    
with open('../Cleansed_Data/y.pkl', 'rb') as f:
    y = pickle.load(f)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=30, 
                                                    stratify=y, 
                                                    random_state=42)

# %%
rf_tf_pipe = Pipeline([
    ('pca', PCA()),
    ('tfidf', TfidfVectorizer(stop_words='english', 
                              encoding='unicode-escape')),
    ('rf', RandomForestClassifier())
])

# %%
rf_tf_params = {
    'tfidf__min_df': list(range(1,6)),
    'tfidf__max_df': list(np.linspace(.5, 1, 10)),
    'rf__max_depth': list(np.linspace(5, 500, 10)),
    'rf__min_samples_leaf': list(range(1,10)),
    'rf__n_estimators': [10, 50, 100],
}

# %%
grid = GridSearchCV(rf_tf_pipe, 
                    rf_tf_params,
                        n_jobs=3,)

# %%
grid.fit(X_train, y_train)

# %%
# grid.score(X_train, y_train)

# %%
# grid.score(X_test, y_test)

# %%
X_train.shape
# Out:
# (8445, 167)

# %% [markdown]
# --------
#
# # Neural Network - Regression Model:
#
# ### Importing the Data:

# %%
with open('../Cleansed_Data/X.pkl', 'rb') as f:
    X = pickle.load(f)
    
with open('../Cleansed_Data/y.pkl', 'rb') as f:
    y = pickle.load(f)

# %%
X.shape
# Out:
# (8475, 167)

# %% [markdown]
# ### Train/Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=30, 
                                                    stratify=y, 
                                                    random_state=42)

# %% [markdown]
# ### Scaling and Fitting:

# %%
ss = StandardScaler()

X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

X_train.shape[1]
# Out:
# 167

# %%
# pca = PCA()
# ss = StandardScaler()
# Xs = pca.fit_transform(X_train)

# pca = PCA(n_components=2)
# X_train = pca.fit_transform(Xs)

# %% [markdown]
# ### Creating a Regression Model:

# %%
model = Sequential()

# n_input = X_train.shape[1]
# n_hidden = n_input
# n_output = 1

# model.add(Dense(n_hidden, input_dim=n_input, activation='relu'))
# model.add(Dense(n_output, activation='sigmoid'))
# model.add(Dropout(.4))
# model.add(Dense(n_output, activation='sigmoid'))
# model.add(Dense(1, activation='sigmoid'))


model.add(Dense(42, activation='relu', input_dim=X_train.shape[1]))
model.add(Dropout(.5))
model.add(Dense(20, activation='relu'))
model.add(Dropout(.5))
model.add(Dense(5, activation='relu'))
model.add(Dense(1))

# %% [markdown]
# ###  Compiling the Model:

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %% [markdown]
# ###  Fitting the Model:

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32, verbose=0)

# %%
model.predict(X_test).mean()
# Out:
# 0.059175123

# %%
train_loss = history.history['loss'][5:]
test_loss = history.history['val_loss'][5:]
plt.plot(train_loss, label='Training loss')
plt.plot(test_loss, label='Testing loss')
plt.legend();

# %%
last_step = 0
for i, step in enumerate(history.history['val_loss']):
    print(f'{i}: {last_step - step}')
    last_step = step
# Out:
# 0: -0.1396215260028839
# 1: 0.0045127421617507935
# 2: 0.017387226223945618
# 3: 0.014932557940483093
# 4: 0.0129198357462883
#   0.05638125278474736,
#   0.05446116025187406,
#   0.0536921325218828,
#   0.05284987436359348,
#   0.05292106807461287,
#   0.05261520769553509,
#   0.05231709262083768,
#   0.052309147083702844,
#   0.051585184481455916,
#   0.051696383551671846,
#   0.05167034518143494,
#   0.051669760539911604,
#   0.05146750418420786,
#   0.05151038180359586,
#   0.05159346943885494,
#   0.05170560443521322,
#   0.051622875062158784,
#   0.051068528466778014,
#   0.051216955118591506,
#   0.05139045916591998,
#   0.05144580010304866,
#   0.05101381624200204,
#   0.051137836568378454,
#   0.05117355554043153,
#   0.05119951806329477,
#   0.051105413810874384,
#   0.05088562605877188,
#   0.05102542918627611,
#   0.05097609003526068,
#   0.05105447903928353,
#   0.05110805069927353,
#   0.05108364300660088,
#   0.0512804500815994,
#   0.05070654371738999]}

# %% [markdown]
# ----------
#
# # Binary Classification:

# %%
# Check number of inputs
print(X_train.shape[1])
layer1 = X_train.shape[1]
layer2 = 6

# %%
model = Sequential()
model.add(Dense(layer1, activation='relu', input_dim=X_train_ss.shape[1])) #Makes this dynamic
model.add(Dropout(.4))
model.add(Dense(layer2, activation='relu')) #Makes this dynamic
model.add(Dense(1, activation='sigmoid'))

# %%
adam = Adam(lr=0.001)
model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])  #mean_squared_error

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, verbose=0)

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, verbose=0)

# %%
history.history.keys()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
train_loss = history.history['loss']
test_loss = history.history['val_loss']
plt.plot(train_loss, label='Training loss')
plt.plot(test_loss, label='Testing loss')
plt.legend()

# %%
model.predict(X_test).mean()
# Out:
# 0.07152803

# %%
X.T
# Out:
#                                      0          1          2          3     \
# Latitude                        41.867108  41.867108  41.862292  41.896282
# Longitude                      -87.654224 -87.654224 -87.648860 -87.655232
# NumMosquitos                     1.000000   2.000000   1.000000   1.000000
# BR                               1.000000   1.000000   1.000000   1.000000
# HZ                               1.000000   1.000000   1.000000   1.000000
# RA                               0.000000   0.000000   0.000000   0.000000
# TSRA                             0.000000   0.000000   0.000000   0.000000
# VCTS                             0.000000   0.000000   0.000000   0.000000
# FU                               0.000000   0.000000   0.000000   0.000000
# TS                               0.000000   0.000000   0.000000   0.000000
# DZ                               0.000000   0.000000   0.000000   0.000000
# BCFG                             0.000000   0.000000   0.000000   0.000000
# FG+                              0.000000   0.000000   0.000000   0.000000
# MIFG                             0.000000   0.000000   0.000000   0.000000
# FG                               0.000000   0.000000   0.000000   0.000000
# SQ                               0.000000   0.000000   0.000000   0.000000
# SN                               0.000000   0.000000   0.000000   0.000000
# VCFG                             0.000000   0.000000   0.000000   0.000000
# GR                               0.000000   0.000000   0.000000   0.000000
# TavgC                           24.166667  24.166667  24.166667  24.166667
# TmaxC                           31.111111  31.111111  31.111111  31.111111
# TminC                           16.944444  16.944444  16.944444  16.944444
# DewPointC                       14.722222  14.722222  14.722222  14.722222
# relative_humidity               55.614546  55.614546  55.614546  55.614546
# rain                             0.000000   0.000000   0.000000   0.000000
# ideal_environment                0.000000   0.000000   0.000000   0.000000
# ideal_feeding                    0.000000   0.000000   0.000000   0.000000
# photoperiod                     15.600000  15.600000  15.600000  15.600000
# FU                               0.000000   0.000000    ...       0.000000
# TS                               0.000000   0.000000    ...       0.000000
# DZ                               0.000000   0.000000    ...       0.000000
# BCFG                             0.000000   0.000000    ...       0.000000
# FG+                              0.000000   0.000000    ...       0.000000
# MIFG                             0.000000   0.000000    ...       0.000000
# FG                               0.000000   0.000000    ...       0.000000
# SQ                               0.000000   0.000000    ...       0.000000
# SN                               0.000000   0.000000    ...       0.000000
# VCFG                             0.000000   0.000000    ...       0.000000
# GR                               0.000000   0.000000    ...       0.000000
# TavgC                           24.166667  24.166667    ...      17.777778
# TmaxC                           31.111111  31.111111    ...      23.888889
# TminC                           16.944444  16.944444    ...      11.388889
# DewPointC                       14.722222  14.722222    ...      11.111111
# relative_humidity               55.614546  55.614546    ...      65.042822
# rain                             0.000000   0.000000    ...       0.000000
# ideal_environment                0.000000   0.000000    ...       1.000000
# ideal_feeding                    0.000000   0.000000    ...       1.000000
# photoperiod                     15.600000  15.600000    ...      12.650000
# TavgC_1_back                    18.333333  18.333333    ...      16.944444
# TavgC_2_back                    19.166667  19.166667    ...      18.888889
# ...                                   ...        ...    ...            ...
# ideal_feeding_12_back            0.000000   0.000000    ...       0.500000
# ideal_feeding_13_back            0.000000   0.000000    ...       0.000000
# ideal_feeding_14_back            0.000000   0.000000    ...       0.000000
# photoperiod_1_back              15.583333  15.583333    ...      12.033333
# photoperiod_2_back              15.566667  15.566667    ...      12.083333
# photoperiod_3_back              15.550000  15.550000    ...      12.133333
# photoperiod_4_back              15.516667  15.516667    ...      12.166667
# photoperiod_5_back              15.483333  15.483333    ...      12.216667
# photoperiod_6_back              15.450000  15.450000    ...      12.266667
# photoperiod_7_back              15.433333  15.433333    ...      12.316667
# photoperiod_8_back              15.400000  15.400000    ...      12.350000
# photoperiod_9_back              15.366667  15.366667    ...      12.416667
# photoperiod_10_back             15.333333  15.333333    ...      12.466667
# photoperiod_11_back             15.300000  15.300000    ...      13.200000
# photoperiod_12_back             15.266667  15.266667    ...      13.250000
# photoperiod_13_back             15.233333  15.233333    ...      13.300000
# photoperiod_14_back             15.200000  15.200000    ...      13.350000
# Month_05                         1.000000   1.000000    ...       0.000000
# Month_06                         0.000000   0.000000    ...       0.000000
# Month_07                         0.000000   0.000000    ...       0.000000
# Month_08                         0.000000   0.000000    ...       0.000000
# Month_09                         0.000000   0.000000    ...       1.000000
# Month_10                         0.000000   0.000000    ...       0.000000
# Species_CULEX ERRATICUS          0.000000   0.000000    ...       0.000000
# Species_CULEX PIPIENS            0.000000   0.000000    ...       1.000000
# Species_CULEX PIPIENS/RESTUANS   1.000000   0.000000    ...       0.000000
# Species_CULEX RESTUANS           0.000000   1.000000    ...       0.000000
# Species_CULEX SALINARIUS         0.000000   0.000000    ...       0.000000
# Species_CULEX TARSALIS           0.000000   0.000000    ...       0.000000
# Species_CULEX TERRITANS          0.000000   0.000000    ...       0.000000
#
#                                      8466       8467       8468       8469  \
# Latitude                        41.750498  41.750498  41.673408  41.673408
# photoperiod_12_back             13.250000  13.250000  13.250000  13.250000
# photoperiod_13_back             13.300000  13.300000  13.300000  13.300000
# photoperiod_14_back             13.350000  13.350000  13.350000  13.350000
# Month_05                         0.000000   0.000000   0.000000   0.000000
# Month_06                         0.000000   0.000000   0.000000   0.000000
# Month_07                         0.000000   0.000000   0.000000   0.000000
# Month_08                         0.000000   0.000000   0.000000   0.000000
# Month_09                         1.000000   1.000000   1.000000   1.000000
# Month_10                         0.000000   0.000000   0.000000   0.000000
# Species_CULEX ERRATICUS          0.000000   0.000000   0.000000   0.000000
# Species_CULEX PIPIENS            1.000000   0.000000   0.000000   0.000000
# Species_CULEX PIPIENS/RESTUANS   0.000000   1.000000   1.000000   1.000000
# Species_CULEX RESTUANS           0.000000   0.000000   0.000000   0.000000
# Species_CULEX SALINARIUS         0.000000   0.000000   0.000000   0.000000
# Species_CULEX TARSALIS           0.000000   0.000000   0.000000   0.000000
# Species_CULEX TERRITANS          0.000000   0.000000   0.000000   0.000000
#
#                                      8474
# Latitude                        41.793818
# Longitude                      -87.654234
# NumMosquitos                     8.000000
# BR                               1.000000
# HZ                               0.000000
# RA                               0.000000
# TSRA                             0.000000
# VCTS                             0.000000
# FU                               0.000000
# TS                               0.000000
# DZ                               0.000000
# BCFG                             0.000000
# FG+                              0.000000
# MIFG                             0.000000
# FG                               0.000000
# SQ                               0.000000
# SN                               0.000000
# VCFG                             0.000000
# GR                               0.000000
# TavgC                           17.777778
# TmaxC                           23.888889
# TminC                           11.388889
# DewPointC                       11.111111
# relative_humidity               65.042822
# rain                             0.000000
# ideal_environment                1.000000
# ideal_feeding                    1.000000
# photoperiod                     12.650000
# TavgC_1_back                    16.944444
# TavgC_2_back                    18.888889
# ...                                   ...
# ideal_feeding_12_back            0.500000
# ideal_feeding_13_back            0.000000
# ideal_feeding_14_back            0.000000
# photoperiod_1_back              12.033333
# photoperiod_2_back              12.083333
# photoperiod_3_back              12.133333
# photoperiod_4_back              12.166667
# photoperiod_5_back              12.216667
# photoperiod_6_back              12.266667
# photoperiod_7_back              12.316667
# photoperiod_8_back              12.350000
# photoperiod_9_back              12.416667
# photoperiod_10_back             12.466667
# photoperiod_11_back             13.200000
# photoperiod_12_back             13.250000
# photoperiod_13_back             13.300000
# photoperiod_14_back             13.350000
# Month_05                         0.000000
# Month_06                         0.000000
# Month_07                         0.000000
# Month_08                         0.000000
# Month_09                         1.000000
# Month_10                         0.000000
# Species_CULEX ERRATICUS          0.000000
# Species_CULEX PIPIENS            0.000000
# Species_CULEX PIPIENS/RESTUANS   1.000000
# Species_CULEX RESTUANS           0.000000
# Species_CULEX SALINARIUS         0.000000
# Species_CULEX TARSALIS           0.000000
# Species_CULEX TERRITANS          0.000000
#
# [167 rows x 8475 columns]

# %%
# ss = StandardScaler()
# pca = PCA()

# pipe = Pipeline([
#     ('ss', ss),
#     ('pca', PCA),
# ])

# pipeline = pipe.fit_transform(X)

# print(cross_val_score(lr,pipeline, y, cv=5).mean())
